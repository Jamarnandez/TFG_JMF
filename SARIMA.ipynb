# %% [markdown]
# # Definición de variables globales y constantes

# %% [markdown]
# En esta parte del código importaremos las bibliotecas y se definirán las variables globales y constantes

# %%
from numpy import float64
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt # basic plotting
import seaborn as sns # for prettier plots
import plotly.graph_objs as go
from plotly.offline import iplot
pd.options.mode.chained_assignment = None  # default='warn
import pytz



##### VARIABLES GLOBALES #####
## Origen de datos ##
files = ['https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/ene_mo18.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/feb_mo18.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/feb_mo18.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/mar_mo18.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/abr_mo18.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/may_mo18.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/jun_mo18.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/jul_mo18.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/ago_mo18.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/sep_mo18.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/oct_mo18.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/nov_mo18.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/dic_mo18.csv',

        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/ene_mo19.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/feb_mo19.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/feb_mo19.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/mar_mo19.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/abr_mo19.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/may_mo19.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/jun_mo19.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/jul_mo19.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/ago_mo19.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/sep_mo19.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/oct_mo19.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/nov_mo19.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/dic_mo19.csv',

        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/ene_mo20.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/feb_mo20.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/feb_mo20.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/mar_mo20.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/abr_mo20.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/may_mo20.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/jun_mo20.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/jul_mo20.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/ago_mo20.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/sep_mo20.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/oct_mo20.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/nov_mo20.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/dic_mo20.csv',

        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/ene_mo21.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/feb_mo21.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/feb_mo21.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/mar_mo21.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/abr_mo21.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/may_mo21.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/jun_mo21.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/jul_mo21.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/ago_mo21.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/sep_mo21.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/oct_mo21.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/nov_mo21.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/dic_mo21.csv',

        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/ene_mo22.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/feb_mo22.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/feb_mo22.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/mar_mo22.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/abr_mo22.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/may_mo22.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/jun_mo22.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/jul_mo22.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/ago_mo22.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/sep_mo22.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/oct_mo22.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/nov_mo22.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/dic_mo22.csv',

        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/ene_mo23.csv',
        'https://raw.githubusercontent.com/Jamarnandez/DatosTFG/main/feb_mo23.csv']


## Variables globales para selección de las muestras ##
magnitud = 8
est_pza_espania = 4
est_barr_pilar = 5
est_escuelas_aguirre = 8
est_paseo_castellana = 48
start_date = "2022-7-01 00:00:00"
end_date = "2022-12-31 23:00:00" #"2023-02-28 23:00:00"
start_date_dt = "2022-7-01"


##################################################################
## En este punto se definen los diccionarios dicV y dicH para   ##
## tipificar las columnas que contienen la información de los   ##
## valores de las muestras. Estos diccionarios se usarán en la  ##
## función time_serie(dataframe) para crear la serie temporal   ##
##################################################################
dicV = {1:"V01", 2:"V02", 3:"V03", 4:"V04", 5:"V05", 6:"V06", 7:"V07", 8:"V08", 9:"V09", 10:"V10", 11:"V11", 12:"V12", 13:"V13"
      , 14:"V14", 15:"V15", 16:"V16", 17:"V17", 18:"V18", 19:"V19", 20:"V20", 21:"V21", 22:"V22", 23:"V23", 24:"V24"}
dicH = {1:"H01", 2:"H02", 3:"H03", 4:"H04", 5:"H05", 6:"H06", 7:"H07", 8:"H08", 9:"H09", 10:"H10", 11:"H11", 12:"H12", 13:"H13"
      , 14:"H14", 15:"H15", 16:"H16", 17:"H17", 18:"H18", 19:"H19", 20:"H20", 21:"H21", 22:"H22", 23:"H23", 24:"H24"}

# %% [markdown]
# # Definición de funciones

# %%
################################# DEFINICIÓN DE FUNCIONES #################################

#########################################################
## Lectura de datos desde csv del repositorio de datos ##
#########################################################
def lee_datos(files_var):
  dataset = pd.read_csv(files[0], sep=';', dtype = {'PROVINCIA': int, 'MUNICIPIO': int, 'ESTACION': int, 'MAGNITUD': int
                                                    , 'PUNTO_MUESTREO': str, 'ANO': int, 'MES': int, 'DIA': int
                                                    , 'H01': float64, 'V01': str, 'H02': float64, 'V02': str, 'H03': float64, 'V03': str
                                                    , 'H04': float64, 'V05': str, 'H05': float64, 'V05': str, 'H06': float64, 'V06': str
                                                    , 'H07': float64, 'V07': str, 'H08': float64, 'V08': str, 'H09': float64, 'V09': str
                                                    , 'H10': float64, 'V10': str, 'H11': float64, 'V11': str, 'H12': float64, 'V12': str
                                                    , 'H13': float64, 'V13': str, 'H14': float64, 'V14': str, 'V15': float64, 'V15': str
                                                    , 'H16': float64, 'V16': str, 'H17': float64, 'V17': str, 'H18': float64, 'V18': str
                                                    , 'H19': float64, 'V19': str, 'H20': float64, 'V20': str, 'H21': float64, 'V21': str
                                                    , 'H22': float64, 'V22': str, 'H23': float64, 'V23': str, 'H24': float64, 'V24': str})
  df_concat = dataset
  for i in range(1, len(files)):
    dataset = pd.read_csv(files[i], sep=';', dtype = {'PROVINCIA': int, 'MUNICIPIO': int, 'ESTACION': int, 'MAGNITUD': int
                                                    , 'PUNTO_MUESTREO': str, 'ANO': int, 'MES': int, 'DIA': int
                                                    , 'H01': float64, 'V01': str, 'H02': float64, 'V02': str, 'H03': float64, 'V03': str
                                                    , 'H04': float64, 'V05': str, 'H05': float64, 'V05': str, 'H06': float64, 'V06': str
                                                    , 'H07': float64, 'V07': str, 'H08': float64, 'V08': str, 'H09': float64, 'V09': str
                                                    , 'H10': float64, 'V10': str, 'H11': float64, 'V11': str, 'H12': float64, 'V12': str
                                                    , 'H13': float64, 'V13': str, 'H14': float64, 'V14': str, 'V15': float64, 'V15': str
                                                    , 'H16': float64, 'V16': str, 'H17': float64, 'V17': str, 'H18': float64, 'V18': str
                                                    , 'H19': float64, 'V19': str, 'H20': float64, 'V20': str, 'H21': float64, 'V21': str
                                                    , 'H22': float64, 'V22': str, 'H23': float64, 'V23': str, 'H24': float64, 'V24': str})
    df_concat = pd.concat([df_concat, dataset]).reset_index(drop=True).drop_duplicates()

  return df_concat




#######################################################################
## La función filtra_estaciones(df) elimina todas las estaciones     ##
## que no van a ser objeto de estudio en este trabajo. en este       ##
## caso, se han seleccionado las estaciones:                         ##
##      -> 28079004 - Plaza de España                                ##
##      -> 28079008 - Escuelas Aguirre                               ##
##      -> 28079048 - Paseo Castellana                               ##
#######################################################################
def filtra_estaciones(df):
  g = 0
  while len(df) > 3:
    if df[g] != est_barr_pilar and df[g] != est_escuelas_aguirre and df[g] != est_paseo_castellana:
      df.remove(df[g])
    else:
      g+=1
  return df

##################################################################
## La función time_serie(df) convierte el dataframe de entrada  ##
## en una serie temporal, creando la columna DATETIME calculada ##
## a partir de las columnas FECHA y las Columnas que definimos  ##
## previamente en el diccionario creado en el paso anterior     ##
##################################################################
def time_serie(dataset):
  for i in range(1,25):
    dataset_filt = dataset[(dataset[dicV[i]] == 'V')]

    dataset_AUX = dataset_filt[["FECHA", "ESTACION", "MAGNITUD", dicH[i]]]
    if i == 24:
      y = '00'
    else:
      y = str(i)


    dataset_AUX["DATETIME"] = dataset_AUX.apply(lambda x: str(x["FECHA"])[:10] + ' ' + y +':00:00', axis=1)

    dataset_AUX["DATETIME"] = pd.to_datetime(dataset_AUX.loc[:,"DATETIME"], format='%y-%m-%d %H:%M:%S', yearfirst=True, infer_datetime_format=True)

    dataset_AUX.drop('FECHA', axis=1, inplace=True)
    column = str(dicH[i])
    dataset_AUX.rename({column:'MUESTRA'}, axis=1, inplace=True)

    if i == 1:
      dfFinal = dataset_AUX
    else:
      dfFinal = pd.concat([dfFinal, dataset_AUX]).reset_index(drop=True)

  return dfFinal

####################################################################
## La función time_serie_varias_estaciones(dataframe, estaciones) ##
## se crea como una función auxiliar para llamar a la función     ##
## time_serie y así formatear todas las estaciones recogidas en   ##
## el orígen de datos                                             ##
####################################################################
def time_serie_varias_estaciones(dataframe, estaciones):
  i = 1
  for estacion in estaciones:
    df = dataframe[(dataframe['ESTACION'] == estacion)]

    df_time_serie = time_serie(df)

    if i == 1:
      dfFinal = df_time_serie
    else:
      dfFinal = pd.concat([dfFinal, df_time_serie]).reset_index(drop=True)

    i += 1

  return dfFinal


########################################################
## La función crea_calendario(list) se utiliza para   ##
## crear la línea temporal del año y se le añade la   ##
## información de los distintos sensores.             ##
########################################################
def crea_calendario(estaciones, df_datos):
  i = 1
  date_df = pd.date_range(start=start_date, end=end_date, freq="H").astype(str).to_frame(index=False, name="DATETIME")
  for estacion in estaciones:

    data_df = df_datos[(df_datos['ESTACION'] == estacion)]
    data_df = data_df[["DATETIME", "MUESTRA"]]
    data_df = data_df.rename(columns={'MUESTRA':f'''ESTACION_{str(estacion)}'''})
    data_df["DATETIME"] = pd.to_datetime(data_df["DATETIME"], yearfirst=True)
    date_df["DATETIME"] = pd.to_datetime(date_df["DATETIME"], yearfirst=True)

    if i == 1:
      merge_df = date_df.merge(data_df, on=["DATETIME"], how="left")
    else:
      merge_df = merge_df.merge(data_df, on=["DATETIME"], how="left")

    i += 1

  return merge_df



##########################################################
## Definición de la función que usaremos para pintar la ##
## gráfica y mostrar los datos de manera visual         ##
##########################################################
def plot_dataset(df, title):
    data = []
    value1 = go.Scatter(
        x=df.index,
        y=df.value1,
        mode="lines",
        name="ESTACION_8",
        marker=dict(),
        text=df.index,
        line=dict(color="rgba(200,200,100, 1)"),
    )
    data.append(value1)

    value2 = go.Scatter(
        x=df.index,
        y=df.value2,
        mode="lines",
        name="ESTACION_48",
        marker=dict(),
        text=df.index,
        line=dict(color="rgba(100,100,100, 1)"),
    )
    data.append(value2)

    value3 = go.Scatter(
        x=df.index,
        y=df.value3,
        mode="lines",
        name="ESTACION_60",
        marker=dict(),
        text=df.index,
        line=dict(color="rgba(100,300,200, 1)"),
    )
    data.append(value3)

    layout = dict(
        title=title,
        xaxis=dict(title="Date", ticklen=5, zeroline=False),
        yaxis=dict(title="Polutant", ticklen=5, zeroline=False),
    )

    fig = dict(data=data, layout=layout)
    iplot(fig)

# %% [markdown]
# # Código para la lectura y formateo de los datos

# %%
# Lectura de datos a un dataframe
dataset = lee_datos(files)

# Eliminar columnas que no aportan información
dataset.drop('PROVINCIA', axis=1, inplace=True)
dataset.drop('MUNICIPIO', axis=1, inplace=True)
dataset.drop('PUNTO_MUESTREO', axis=1, inplace=True)

## Filtramos por la magnitud que nos interesa estudiar
dataset = dataset[(dataset['MAGNITUD'] == magnitud)]


## Resetear el índice del dataframe y posteriormente eliminarlo
dataset_2 = dataset.iloc[:].reset_index()
dataset_2.drop('index', axis=1, inplace=True)

## Creación de la columna FECHA a partir de las columnas DIA, MES y AÑO
dataset_2["FECHA"] = dataset_2.apply(lambda x: str(x["DIA"])+ '/' + str(x["MES"])+ '/'  + str(x["ANO"]), axis=1)

## Casteo para conversión de la columna fecha al tipo datetime
dataset_2["FECHA"] = pd.to_datetime(dataset_2["FECHA"], dayfirst=True)

## Ordenar el dataframe por la columna FECHA de manera ascendente
dataset_2 = dataset_2.sort_values(by="FECHA", ascending=True)

## Eliminar columnas AÑO, MES y DIA
dataset_2.drop('ANO', axis=1, inplace=True)
dataset_2.drop('MES', axis=1, inplace=True)
dataset_2.drop('DIA', axis=1, inplace=True)

## Nos quedamos con las muestras de las estaciones a estudiar
estaciones = dataset['ESTACION'].unique().tolist()
estaciones = filtra_estaciones(estaciones)

## Llamada a la función time_serie_varias_estaciones(dataframe, estaciones)
df = time_serie_varias_estaciones(dataset_2, estaciones)

df["DATETIME"] = pd.to_datetime(df["DATETIME"], dayfirst=True)

## Ordenar el dataframe por las columnas ESTACION y DATETIME de manera ascendente
df = df.sort_values(by=["ESTACION", "DATETIME"], ascending=True)

df
# Out:
#         ESTACION  MAGNITUD  MUESTRA            DATETIME
# 42463          8         8     34.0 2018-01-01 00:00:00
# 0              8         8     33.0 2018-01-01 01:00:00
# 1862           8         8     64.0 2018-01-01 02:00:00
# 3726           8         8     63.0 2018-01-01 03:00:00
# 5586           8         8     51.0 2018-01-01 04:00:00
# ...          ...       ...      ...                 ...
# 125049        60         8     17.0 2023-02-28 19:00:00
# 126926        60         8     28.0 2023-02-28 20:00:00
# 128807        60         8     30.0 2023-02-28 21:00:00
# 130691        60         8     23.0 2023-02-28 22:00:00
# 132576        60         8     17.0 2023-02-28 23:00:00
#
# [134462 rows x 4 columns]

# %% [markdown]
# Se crea la línea temporal del año y se le añaden los datos de los sensores

# %%
#### 8, 48, 60
estaciones = [8, 48, 60]

merge_df = crea_calendario(estaciones, df)

#merge_df.fillna('0', inplace=True)

merge_df
# Out:
#                 DATETIME  ESTACION_8  ESTACION_48  ESTACION_60
# 0    2022-07-01 00:00:00        32.0         30.0         47.0
# 1    2022-07-01 01:00:00        24.0         13.0         13.0
# 2    2022-07-01 02:00:00        15.0          9.0          8.0
# 3    2022-07-01 03:00:00         9.0          5.0          8.0
# 4    2022-07-01 04:00:00         8.0          4.0          9.0
# ...                  ...         ...          ...          ...
# 4411 2022-12-31 19:00:00        37.0         69.0         56.0
# 4412 2022-12-31 20:00:00        60.0         84.0         60.0
# 4413 2022-12-31 21:00:00        93.0         89.0         68.0
# 4414 2022-12-31 22:00:00       105.0         86.0         67.0
# 4415 2022-12-31 23:00:00        76.0         71.0         58.0
#
# [4416 rows x 4 columns]

# %% [markdown]
# # Gráfica de visualización de datos

# %% [markdown]
# Se pintan los datos correspondientes a los 3 sensores elegidos para el estudio

# %%
df_grafica = merge_df[["DATETIME", "ESTACION_8", "ESTACION_48", "ESTACION_60"]]

#print(type(df_grafica.DATETIME[0]))

df_grafica = df_grafica.set_index(["DATETIME"])
df_grafica.index = pd.to_datetime(df_grafica.index)

if not df_grafica.index.is_monotonic:
    df_grafica = df_grafica.sort_index()

df_grafica = df_grafica.rename(columns={'ESTACION_8': 'value1', 'ESTACION_48': 'value2', 'ESTACION_60': 'value3'})
plot_dataset(df_grafica, title='Samples of polutant')
# Out:
# <ipython-input-5-73cb973db6bd>:8: FutureWarning:
#
# is_monotonic is deprecated and will be removed in a future version. Use is_monotonic_increasing instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Gráfica para observar valores perdidos
#
# Se crea otro tipo de gráfica con el que podemos darnos cuenta a simple vista de qué periodos temporales nos faltan.

# %%
import missingno as msno
# Pivot the data to set the index as the datetime and the different time series along the columns
plot_df = pd.pivot_table(df, index="DATETIME", columns="ESTACION", values="MUESTRA")
# Generate Plot. Since we have a datetime index, we can mention the frequency to decide what do we want on the X axis
msno.matrix(plot_df, freq="M", fontsize=20)
#plt.savefig('imgs/chapter_2/missing_no_full.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# # Interpolación de datos

# %% [markdown]
# A partir de este punto se aborda el problema de muestras que nos faltan en el dataset para cada sensor.
#
# En primer lugar se seleccionará el periodo temporal que se va a estudiar.

# %%
filter_df = merge_df[(merge_df['DATETIME'] >= start_date_dt)]


filter_df
# Out:
#                 DATETIME  ESTACION_8  ESTACION_48  ESTACION_60
# 0    2022-07-01 00:00:00        32.0         30.0         47.0
# 1    2022-07-01 01:00:00        24.0         13.0         13.0
# 2    2022-07-01 02:00:00        15.0          9.0          8.0
# 3    2022-07-01 03:00:00         9.0          5.0          8.0
# 4    2022-07-01 04:00:00         8.0          4.0          9.0
# ...                  ...         ...          ...          ...
# 4411 2022-12-31 19:00:00        37.0         69.0         56.0
# 4412 2022-12-31 20:00:00        60.0         84.0         60.0
# 4413 2022-12-31 21:00:00        93.0         89.0         68.0
# 4414 2022-12-31 22:00:00       105.0         86.0         67.0
# 4415 2022-12-31 23:00:00        76.0         71.0         58.0
#
# [4416 rows x 4 columns]

# %% [markdown]
# A continuación se rellan las muestras vacías con un valor constante, en este caso cero y se establece la columna DATETIME como índice.

# %%
filter_df.fillna(0)

filter_df = filter_df.set_index("DATETIME")

filter_df
# Out:
#                      ESTACION_8  ESTACION_48  ESTACION_60
# DATETIME
# 2022-07-01 00:00:00        32.0         30.0         47.0
# 2022-07-01 01:00:00        24.0         13.0         13.0
# 2022-07-01 02:00:00        15.0          9.0          8.0
# 2022-07-01 03:00:00         9.0          5.0          8.0
# 2022-07-01 04:00:00         8.0          4.0          9.0
# ...                         ...          ...          ...
# 2022-12-31 19:00:00        37.0         69.0         56.0
# 2022-12-31 20:00:00        60.0         84.0         60.0
# 2022-12-31 21:00:00        93.0         89.0         68.0
# 2022-12-31 22:00:00       105.0         86.0         67.0
# 2022-12-31 23:00:00        76.0         71.0         58.0
#
# [4416 rows x 3 columns]

# %% [markdown]
# Acto seguido se realiza el cálculo de la interpolación de valores de las muestras que faltan. Para ello se ha seleccionado el método de interpolación polinomial con un orden 3

# %%
interpolated_station_8 = filter_df['ESTACION_8'].interpolate(method="polynomial", order=3).to_frame()
interpolated_station_8 = interpolated_station_8["ESTACION_8"].round(1).to_frame()

interpolated_station_48 = filter_df['ESTACION_48'].interpolate(method="polynomial", order=3).to_frame()
interpolated_station_48 = interpolated_station_48["ESTACION_48"].round(1).to_frame()

interpolated_station_60 = filter_df['ESTACION_60'].interpolate(method="polynomial", order=3).to_frame()
interpolated_station_60 = interpolated_station_60["ESTACION_60"].round(1).to_frame()

interpolated_stations = interpolated_station_8.merge(interpolated_station_48, on=["DATETIME"], how="left")
interpolated_stations = interpolated_stations.merge(interpolated_station_60, on=["DATETIME"], how="left")

# %%
interpolated_stations
# Out:
#                      ESTACION_8  ESTACION_48  ESTACION_60
# DATETIME
# 2022-07-01 00:00:00        32.0         30.0         47.0
# 2022-07-01 01:00:00        24.0         13.0         13.0
# 2022-07-01 02:00:00        15.0          9.0          8.0
# 2022-07-01 03:00:00         9.0          5.0          8.0
# 2022-07-01 04:00:00         8.0          4.0          9.0
# ...                         ...          ...          ...
# 2022-12-31 19:00:00        37.0         69.0         56.0
# 2022-12-31 20:00:00        60.0         84.0         60.0
# 2022-12-31 21:00:00        93.0         89.0         68.0
# 2022-12-31 22:00:00       105.0         86.0         67.0
# 2022-12-31 23:00:00        76.0         71.0         58.0
#
# [4416 rows x 3 columns]

# %% [markdown]
# # Generación ventana deslizante con uno de los sensores
#
# Se procede a realizar un conjunto dedatos estructurados como ventana deslizante para uno de los sensores, en concreto, la estación número 4

# %%
df_lag = interpolated_stations["ESTACION_8"].to_frame()
input_dim = rows = 48

df_lag
# Out:
#                      ESTACION_8
# DATETIME
# 2022-07-01 00:00:00        32.0
# 2022-07-01 01:00:00        24.0
# 2022-07-01 02:00:00        15.0
# 2022-07-01 03:00:00         9.0
# 2022-07-01 04:00:00         8.0
# ...                         ...
# 2022-12-31 19:00:00        37.0
# 2022-12-31 20:00:00        60.0
# 2022-12-31 21:00:00        93.0
# 2022-12-31 22:00:00       105.0
# 2022-12-31 23:00:00        76.0
#
# [4416 rows x 1 columns]

# %%
df_lag['date'] = df_lag.index
df_lag = df_lag.rename(columns={'ESTACION_8':'data'})

df_lag
# Out:
#                       data                date
# DATETIME
# 2022-07-01 00:00:00   32.0 2022-07-01 00:00:00
# 2022-07-01 01:00:00   24.0 2022-07-01 01:00:00
# 2022-07-01 02:00:00   15.0 2022-07-01 02:00:00
# 2022-07-01 03:00:00    9.0 2022-07-01 03:00:00
# 2022-07-01 04:00:00    8.0 2022-07-01 04:00:00
# ...                    ...                 ...
# 2022-12-31 19:00:00   37.0 2022-12-31 19:00:00
# 2022-12-31 20:00:00   60.0 2022-12-31 20:00:00
# 2022-12-31 21:00:00   93.0 2022-12-31 21:00:00
# 2022-12-31 22:00:00  105.0 2022-12-31 22:00:00
# 2022-12-31 23:00:00   76.0 2022-12-31 23:00:00
#
# [4416 rows x 2 columns]

# %% [markdown]
# # Análisis de serie temporal para SARIMA

# %%
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.stattools import adfuller
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook
import numpy as np
import pandas as pd
from itertools import product
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
plt.figure(figsize=[20, 9.5]); # Establecer dimensiones de la figura
plt.plot(df_lag['date'], df_lag['data']) # Datos en eje x y eje y
plt.title('Niveles de NO2 horaria en Madrid')
plt.ylabel('Niveles de Polución')
plt.xlabel('Fecha')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
plot_pacf(df_lag['data']);
plot_acf(df_lag['data']);

# %%
ad_fuller_result = adfuller(df_lag['data'])
print(f'ADF Statistic: {ad_fuller_result[0]}')
print(f'p-value: {ad_fuller_result[1]}')
# Out:
# ADF Statistic: -6.880996138753846
# p-value: 1.433594153705723e-09

# %%
#df_lag['data'] = np.log(df_lag['data'])
#df_lag['data'] = df_lag['data'].diff()
#df_lag = df_lag.drop(df_lag.index[0])

# %%
#ad_fuller_result = adfuller(df_lag['data'])
#print(f'ADF Statistic: {ad_fuller_result[0]}')
#print(f'p-value: {ad_fuller_result[1]}')

# %%
df_auto_sarima = df_lag.copy()

# %%
#plt.figure(figsize=[20, 9.5]); # Establecer dimensiones de la figura
#plt.plot(df_lag['date'], df_lag['data']) # Datos en eje x y eje y
#plt.title('Niveles de NO2 horaria en Madrid')
#plt.ylabel('Niveles de Polución')
#plt.xlabel('Fecha')
#plt.xticks(rotation=90)
#plt.grid(True)
#plt.show()

# %%
#plot_pacf(df_lag['data']);
#plot_acf(df_lag['data']);

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Entrenamiento de modelo SARIMA AUTOSARIMA

# %%
data = df_auto_sarima.copy()

#data.drop('date', axis=1, inplace=True)

data = data.set_index('date')

#data[:]

# %%
# !pip install pmdarima #!pip3 install pyramid-arima
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 7.9 MB/s eta 0:00:00
# ...

# %%
import pmdarima as pm

# Seasonal - fit stepwise auto-ARIMA
smodel = pm.auto_arima(data, start_p=0, start_q=0,
                         test='adf',
                         max_p=3, max_q=3, m=7,
                         start_P=0, start_Q=0,
                         max_P=3, max_Q=3,
                         seasonal=True,
                         d=None, D=0, trace=True,
                         error_action='ignore',
                         suppress_warnings=True,
                         stepwise=True)

smodel.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[7] intercept   : AIC=39272.421, Time=0.21 sec
#  ARIMA(1,0,0)(1,0,0)[7] intercept   : AIC=35001.250, Time=4.24 sec
#  ARIMA(0,0,1)(0,0,1)[7] intercept   : AIC=36784.998, Time=7.66 sec
#  ARIMA(0,0,0)(0,0,0)[7]             : AIC=44979.898, Time=0.09 sec
#  ARIMA(1,0,0)(0,0,0)[7] intercept   : AIC=35018.640, Time=0.53 sec
#  ARIMA(1,0,0)(2,0,0)[7] intercept   : AIC=34999.578, Time=20.79 sec
#  ARIMA(1,0,0)(3,0,0)[7] intercept   : AIC=35000.350, Time=26.29 sec
#  ARIMA(1,0,0)(2,0,1)[7] intercept   : AIC=35002.069, Time=12.10 sec
#  ARIMA(1,0,0)(1,0,1)[7] intercept   : AIC=35000.551, Time=8.10 sec
#  ARIMA(1,0,0)(3,0,1)[7] intercept   : AIC=34998.580, Time=53.13 sec
#  ARIMA(1,0,0)(3,0,2)[7] intercept   : AIC=34877.116, Time=50.84 sec
#  ARIMA(1,0,0)(2,0,2)[7] intercept   : AIC=34910.107, Time=30.80 sec
#  ARIMA(1,0,0)(3,0,3)[7] intercept   : AIC=inf, Time=53.70 sec
# ...

# %%
smodel.plot_diagnostics(figsize=(18,14))

plt.show()

# %%
# Forecast
n_periods = 24
fitted, confint = smodel.predict(n_periods=n_periods, return_conf_int=True)
index_of_fc = pd.date_range(data.index[-1], periods = n_periods, freq='H')

# make series for plotting purpose
fitted_series = pd.Series(fitted, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.figure().set_figwidth(15)
plt.plot(data)
plt.plot(fitted_series, color='darkgreen')
plt.fill_between(lower_series.index,
                 lower_series,
                 upper_series,
                 color='g', alpha=.15)

plt.title("SARIMA - Predicción final de contaminantes - Niveles de NO2")
plt.show()

# %%
df_fitted_series = pd.DataFrame(fitted_series)
df_fitted_series=df_fitted_series.rename(columns={0:'data'})

# %%
import plotly.offline as pyo

def plot_predictions(df_result, fitted):
    data = []

    value = go.Scatter(
        x=df_result.index,
        y=df_result.data,
        mode="lines",
        name="Valores",
        marker=dict(),
        text=df_result.index,
        line=dict(color="rgba(0,0,0, 0.3)"),
    )
    data.append(value)


    prediction = go.Scatter(
        x=fitted.index,
        y=fitted.data,
        mode="lines",
        line={"dash": "dot"},
        name='Predicciones',
        marker=dict(),
        text=df_result.index,
        opacity=0.8,
    )
    data.append(prediction)

    layout = dict(
        title="Valores actuales y Predicciones de NO2",
        xaxis=dict(title="Línea temporal", ticklen=5, zeroline=False),
        yaxis=dict(title="Valores", ticklen=5, zeroline=False),
    )

    fig = dict(data=data, layout=layout)
    iplot(fig)



plot_predictions(data, df_fitted_series)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data_2 = data[3000:]
#data_2

# %%
# Forecast
n_periods = 24
fitted, confint = smodel.predict(n_periods=n_periods, return_conf_int=True)
index_of_fc = pd.date_range(data.index[-1], periods = n_periods, freq='H')

# make series for plotting purpose
fitted_series = pd.Series(fitted, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.figure().set_figwidth(15)
plt.plot(data_2)
plt.plot(fitted_series, color='darkgreen')
plt.fill_between(lower_series.index,
                 lower_series,
                 upper_series,
                 color='g', alpha=.15)

plt.title("SARIMA - Predicción final de contaminantes - Niveles de NO2")
plt.show()
